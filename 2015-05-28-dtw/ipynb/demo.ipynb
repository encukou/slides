# %%
import numpy
import scipy.stats
import scipy.signal
import dtw
import librosa
# %pylab inline

SAMPLE_RATE = 22050
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
signal1, _sample_rate = librosa.load("../media/a.wav", sr=SAMPLE_RATE)
signal2, _sample_rate = librosa.load("../media/b.wav", sr=SAMPLE_RATE)

# %%
plot(signal1[500:1500])

# %%
plot(signal2[500:1500])

# %%
mfcc1 = librosa.feature.mfcc(signal1, SAMPLE_RATE, n_mfcc=10)
mfcc2 = librosa.feature.mfcc(signal2, SAMPLE_RATE, n_mfcc=10)

# %%
figure(figsize=(8, 2))
librosa.display.specshow(mfcc1[:,:100])

# %%
figure(figsize=(8, 2))
librosa.display.specshow(mfcc2[:,:100])

# %%
figure(figsize=(16, 2))
librosa.display.specshow(mfcc2[:,:])
