# %%
import os
import sys
import dis

# %% [markdown]
# # The Future: No more bytecode!

# %%
print(sys.version)
# Out:
# 3.6.0a2+ (default, Jun 22 2016, 13:01:41)
# [GCC 6.1.1 20160510 (Red Hat 6.1.1-2)]

# %%
# !cat module.py
# Out:
# a = 3
# b = 'Hello '
# print(a * b)
#
# def func(a=1, *b, **c):
#     return 7 + 3

# %%
# !python -m dis module.py
# Out:
#   1           0 LOAD_CONST               0 (3)
#               2 STORE_NAME               0 (a)
#
#   2           4 LOAD_CONST               1 ('Hello ')
#               6 STORE_NAME               1 (b)
#
#   3           8 LOAD_NAME                2 (print)
#              10 LOAD_NAME                0 (a)
#              12 LOAD_NAME                1 (b)
#              14 BINARY_MULTIPLY
#              16 CALL_FUNCTION            1 (1 positional, 0 keyword pair)
#              18 POP_TOP
#
#   5          20 LOAD_CONST               6 ((1,))
#              22 LOAD_CONST               3 (<code object func at 0x7f3317b891c0, file "module.py", line 5>)
#              24 LOAD_CONST               4 ('func')
#              26 MAKE_FUNCTION            1
#              28 STORE_NAME               3 (func)
#              30 LOAD_CONST               5 (None)
#              32 RETURN_VALUE

# %%
filename = os.path.abspath('module.py')
with open(filename) as f:
    code = compile(f.read(), filename=filename, mode='exec')
code
# Out:
# <code object <module> at 0x7fbc842cbd00, file "/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py", line 1>

# %%
print(list(code.co_code))
# Out:
# [100, 0, 90, 0, 100, 1, 90, 1, 101, 2, 101, 0, 101, 1, 20, 0, 131, 1, 1, 0, 100, 6, 100, 3, 100, 4, 132, 1, 90, 3, 100, 5, 83, 0]

# %%
def print_dis(code):
    line_starts = [a for a, b in dis.findlinestarts(code)]
    for instr in dis.get_instructions(code):
        if instr.offset in line_starts:
            print()
        print('{i.offset:2}:  {i.opcode:3} {arg:>6}: {i.opname}({i.argrepr})'.format(
                i=instr,
                arg='-' if instr.arg is None else instr.arg))

print_dis(code)
# Out:
#  0:  100      0: LOAD_CONST(3)
#  2:   90      0: STORE_NAME(a)
#
#  4:  100      1: LOAD_CONST('Hello ')
#  6:   90      1: STORE_NAME(b)
#
#  8:  101      2: LOAD_NAME(print)
# 10:  101      0: LOAD_NAME(a)
# 12:  101      1: LOAD_NAME(b)
# 14:   20      -: BINARY_MULTIPLY()
# 16:  131      1: CALL_FUNCTION(1 positional, 0 keyword pair)
# 18:    1      -: POP_TOP()
#
# 20:  100      6: LOAD_CONST((1,))
# 22:  100      3: LOAD_CONST(<code object func at 0x7fbc85c51400, file "/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py", line 5>)
# 24:  100      4: LOAD_CONST('func')
# 26:  132      1: MAKE_FUNCTION()
# 28:   90      3: STORE_NAME(func)
# 30:  100      5: LOAD_CONST(None)
# 32:   83      -: RETURN_VALUE()

# %% [markdown]
# ### Summary
# Starting with Python 3.6, there will be no more bytecode. Python is switching to *wordcode*, where each instruction is two bytes long: a byte for the instruction, and a byte for the argument.
# The benefit is that wordcode is faster to run: computers are apparently better at handling two-byte units than a mix of one- and three-byte ones.
#
# The Python developers are using this opportunity to iron out some warts of the instruction set.

# %% [markdown]
# ---
# # Extra section I - extended arguments

# %%
def print_dis(code):
    line_starts = [a for a, b in dis.findlinestarts(code)]
    for instr in dis.get_instructions(code):
        if instr.offset in line_starts:
            print()
        print('{i.offset:2}:  {i.opcode:3} {arg:>6}: {i.opname}({i.argrepr})'.format(
                i=instr,
                arg='-' if instr.arg is None else instr.arg))

# %%
source = ''.join('a={}\n'.format(i) for i in range(260))
code = compile(source, '<file>', 'exec')

print(90, dis.opname[90])
print(100, dis.opname[100])
print(144, dis.opname[144])
print()

print(list(code.co_code))
print_dis(code)
# Out:
# 90 STORE_NAME
# 100 LOAD_CONST
# 144 EXTENDED_ARG
#
# [100, 0, 90, 0, 100, 1, 90, 0, 100, 2, 90, 0, 100, 3, 90, 0, 100, 4, 90, 0, 100, 5, 90, 0, 100, 6, 90, 0, 100, 7, 90, 0, 100, 8, 90, 0, 100, 9, 90, 0, 100, 10, 90, 0, 100, 11, 90, 0, 100, 12, 90, 0, 100, 13, 90, 0, 100, 14, 90, 0, 100, 15, 90, 0, 100, 16, 90, 0, 100, 17, 90, 0, 100, 18, 90, 0, 100, 19, 90, 0, 100, 20, 90, 0, 100, 21, 90, 0, 100, 22, 90, 0, 100, 23, 90, 0, 100, 24, 90, 0, 100, 25, 90, 0, 100, 26, 90, 0, 100, 27, 90, 0, 100, 28, 90, 0, 100, 29, 90, 0, 100, 30, 90, 0, 100, 31, 90, 0, 100, 32, 90, 0, 100, 33, 90, 0, 100, 34, 90, 0, 100, 35, 90, 0, 100, 36, 90, 0, 100, 37, 90, 0, 100, 38, 90, 0, 100, 39, 90, 0, 100, 40, 90, 0, 100, 41, 90, 0, 100, 42, 90, 0, 100, 43, 90, 0, 100, 44, 90, 0, 100, 45, 90, 0, 100, 46, 90, 0, 100, 47, 90, 0, 100, 48, 90, 0, 100, 49, 90, 0, 100, 50, 90, 0, 100, 51, 90, 0, 100, 52, 90, 0, 100, 53, 90, 0, 100, 54, 90, 0, 100, 55, 90, 0, 100, 56, 90, 0, 100, 57, 90, 0, 100, 58, 90, 0, 100, 59, 90, 0, 100, 60, 90, 0, 100, 61, 90, 0, 100, 62, 90, 0, 100, 63, 90, 0, 100, 64, 90, 0, 100, 65, 90, 0, 100, 66, 90, 0, 100, 67, 90, 0, 100, 68, 90, 0, 100, 69, 90, 0, 100, 70, 90, 0, 100, 71, 90, 0, 100, 72, 90, 0, 100, 73, 90, 0, 100, 74, 90, 0, 100, 75, 90, 0, 100, 76, 90, 0, 100, 77, 90, 0, 100, 78, 90, 0, 100, 79, 90, 0, 100, 80, 90, 0, 100, 81, 90, 0, 100, 82, 90, 0, 100, 83, 90, 0, 100, 84, 90, 0, 100, 85, 90, 0, 100, 86, 90, 0, 100, 87, 90, 0, 100, 88, 90, 0, 100, 89, 90, 0, 100, 90, 90, 0, 100, 91, 90, 0, 100, 92, 90, 0, 100, 93, 90, 0, 100, 94, 90, 0, 100, 95, 90, 0, 100, 96, 90, 0, 100, 97, 90, 0, 100, 98, 90, 0, 100, 99, 90, 0, 100, 100, 90, 0, 100, 101, 90, 0, 100, 102, 90, 0, 100, 103, 90, 0, 100, 104, 90, 0, 100, 105, 90, 0, 100, 106, 90, 0, 100, 107, 90, 0, 100, 108, 90, 0, 100, 109, 90, 0, 100, 110, 90, 0, 100, 111, 90, 0, 100, 112, 90, 0, 100, 113, 90, 0, 100, 114, 90, 0, 100, 115, 90, 0, 100, 116, 90, 0, 100, 117, 90, 0, 100, 118, 90, 0, 100, 119, 90, 0, 100, 120, 90, 0, 100, 121, 90, 0, 100, 122, 90, 0, 100, 123, 90, 0, 100, 124, 90, 0, 100, 125, 90, 0, 100, 126, 90, 0, 100, 127, 90, 0, 100, 128, 90, 0, 100, 129, 90, 0, 100, 130, 90, 0, 100, 131, 90, 0, 100, 132, 90, 0, 100, 133, 90, 0, 100, 134, 90, 0, 100, 135, 90, 0, 100, 136, 90, 0, 100, 137, 90, 0, 100, 138, 90, 0, 100, 139, 90, 0, 100, 140, 90, 0, 100, 141, 90, 0, 100, 142, 90, 0, 100, 143, 90, 0, 100, 144, 90, 0, 100, 145, 90, 0, 100, 146, 90, 0, 100, 147, 90, 0, 100, 148, 90, 0, 100, 149, 90, 0, 100, 150, 90, 0, 100, 151, 90, 0, 100, 152, 90, 0, 100, 153, 90, 0, 100, 154, 90, 0, 100, 155, 90, 0, 100, 156, 90, 0, 100, 157, 90, 0, 100, 158, 90, 0, 100, 159, 90, 0, 100, 160, 90, 0, 100, 161, 90, 0, 100, 162, 90, 0, 100, 163, 90, 0, 100, 164, 90, 0, 100, 165, 90, 0, 100, 166, 90, 0, 100, 167, 90, 0, 100, 168, 90, 0, 100, 169, 90, 0, 100, 170, 90, 0, 100, 171, 90, 0, 100, 172, 90, 0, 100, 173, 90, 0, 100, 174, 90, 0, 100, 175, 90, 0, 100, 176, 90, 0, 100, 177, 90, 0, 100, 178, 90, 0, 100, 179, 90, 0, 100, 180, 90, 0, 100, 181, 90, 0, 100, 182, 90, 0, 100, 183, 90, 0, 100, 184, 90, 0, 100, 185, 90, 0, 100, 186, 90, 0, 100, 187, 90, 0, 100, 188, 90, 0, 100, 189, 90, 0, 100, 190, 90, 0, 100, 191, 90, 0, 100, 192, 90, 0, 100, 193, 90, 0, 100, 194, 90, 0, 100, 195, 90, 0, 100, 196, 90, 0, 100, 197, 90, 0, 100, 198, 90, 0, 100, 199, 90, 0, 100, 200, 90, 0, 100, 201, 90, 0, 100, 202, 90, 0, 100, 203, 90, 0, 100, 204, 90, 0, 100, 205, 90, 0, 100, 206, 90, 0, 100, 207, 90, 0, 100, 208, 90, 0, 100, 209, 90, 0, 100, 210, 90, 0, 100, 211, 90, 0, 100, 212, 90, 0, 100, 213, 90, 0, 100, 214, 90, 0, 100, 215, 90, 0, 100, 216, 90, 0, 100, 217, 90, 0, 100, 218, 90, 0, 100, 219, 90, 0, 100, 220, 90, 0, 100, 221, 90, 0, 100, 222, 90, 0, 100, 223, 90, 0, 100, 224, 90, 0, 100, 225, 90, 0, 100, 226, 90, 0, 100, 227, 90, 0, 100, 228, 90, 0, 100, 229, 90, 0, 100, 230, 90, 0, 100, 231, 90, 0, 100, 232, 90, 0, 100, 233, 90, 0, 100, 234, 90, 0, 100, 235, 90, 0, 100, 236, 90, 0, 100, 237, 90, 0, 100, 238, 90, 0, 100, 239, 90, 0, 100, 240, 90, 0, 100, 241, 90 ...
#
#  0:  100      0: LOAD_CONST(0)
#  2:   90      0: STORE_NAME(a)
#
#  4:  100      1: LOAD_CONST(1)
#  6:   90      0: STORE_NAME(a)
#
#  8:  100      2: LOAD_CONST(2)
# 10:   90      0: STORE_NAME(a)
#
# 12:  100      3: LOAD_CONST(3)
# 14:   90      0: STORE_NAME(a)
#
# 16:  100      4: LOAD_CONST(4)
# 18:   90      0: STORE_NAME(a)
#
# 20:  100      5: LOAD_CONST(5)
# 22:   90      0: STORE_NAME(a)
#
# 24:  100      6: LOAD_CONST(6)
# 26:   90      0: STORE_NAME(a)
#
# 28:  100      7: LOAD_CONST(7)
# 30:   90      0: STORE_NAME(a)
#
# 32:  100      8: LOAD_CONST(8)
# 34:   90      0: STORE_NAME(a)
#
# 36:  100      9: LOAD_CONST(9)
# 38:   90      0: STORE_NAME(a)
#
# 40:  100     10: LOAD_CONST(10)
# 42:   90      0: STORE_NAME(a)
#
# 44:  100     11: LOAD_CONST(11)
# 46:   90      0: STORE_NAME(a)
#
# 48:  100     12: LOAD_CONST(12)
# 50:   90      0: STORE_NAME(a)
#
# 52:  100     13: LOAD_CONST(13)
# 54:   90      0: STORE_NAME(a)
#
# 56:  100     14: LOAD_CONST(14)
# 58:   90      0: STORE_NAME(a)
#
# 60:  100     15: LOAD_CONST(15)
# 62:   90      0: STORE_NAME(a)
#
# 64:  100     16: LOAD_CONST(16)
# 66:   90      0: STORE_NAME(a)
#
# 68:  100     17: LOAD_CONST(17)
# 70:   90      0: STORE_NAME(a)
#
# 72:  100     18: LOAD_CONST(18)
# 74:   90      0: STORE_NAME(a)
#
# 76:  100     19: LOAD_CONST(19)
# 78:   90      0: STORE_NAME(a)
#
# 80:  100     20: LOAD_CONST(20)
# 82:   90      0: STORE_NAME(a)
#
# 84:  100     21: LOAD_CONST(21)
# 86:   90      0: STORE_NAME(a)
#
# 88:  100     22: LOAD_CONST(22)
# 90:   90      0: STORE_NAME(a)
#
# 92:  100     23: LOAD_CONST(23)
# 94:   90      0: STORE_NAME(a)
#
# 96:  100     24: LOAD_CONST(24)
# 98:   90      0: STORE_NAME(a)
#
# 100:  100     25: LOAD_CONST(25)
# 102:   90      0: STORE_NAME(a)
#
# 104:  100     26: LOAD_CONST(26)
# 106:   90      0: STORE_NAME(a)
#
# 108:  100     27: LOAD_CONST(27)
# 110:   90      0: STORE_NAME(a)
#
# 112:  100     28: LOAD_CONST(28)
# 114:   90      0: STORE_NAME(a)
#
# 116:  100     29: LOAD_CONST(29)
# 118:   90      0: STORE_NAME(a)
#
# 120:  100     30: LOAD_CONST(30)
# 122:   90      0: STORE_NAME(a)
#
# 124:  100     31: LOAD_CONST(31)
# 126:   90      0: STORE_NAME(a)
#
# 128:  100     32: LOAD_CONST(32)
# 130:   90      0: STORE_NAME(a)
#
# 132:  100     33: LOAD_CONST(33)
# 134:   90      0: STORE_NAME(a)
#
# 136:  100     34: LOAD_CONST(34)
# 138:   90      0: STORE_NAME(a)
#
# 140:  100     35: LOAD_CONST(35)
# 142:   90      0: STORE_NAME(a)
#
# 144:  100     36: LOAD_CONST(36)
# 146:   90      0: STORE_NAME(a)
#
# 148:  100     37: LOAD_CONST(37)
# 150:   90      0: STORE_NAME(a)
#
# 152:  100     38: LOAD_CONST(38)
# 154:   90      0: STORE_NAME(a)
#
# 156:  100     39: LOAD_CONST(39)
# 158:   90      0: STORE_NAME(a)
#
# 160:  100     40: LOAD_CONST(40)
# 162:   90      0: STORE_NAME(a)
#
# 164:  100     41: LOAD_CONST(41)
# 166:   90      0: STORE_NAME(a)
#
# 168:  100     42: LOAD_CONST(42)
# 170:   90      0: STORE_NAME(a)
#
# 172:  100     43: LOAD_CONST(43)
# 174:   90      0: STORE_NAME(a)
#
# 176:  100     44: LOAD_CONST(44)
# 178:   90      0: STORE_NAME(a)
#
# 180:  100     45: LOAD_CONST(45)
# 182:   90      0: STORE_NAME(a)
#
# 184:  100     46: LOAD_CONST(46)
# 186:   90      0: STORE_NAME(a)
#
# 188:  100     47: LOAD_CONST(47)
# 190:   90      0: STORE_NAME(a)
#
# 192:  100     48: LOAD_CONST(48)
# 194:   90      0: STORE_NAME(a)
#
# 196:  100     49: LOAD_CONST(49)
# 198:   90      0: STORE_NAME(a)
#
# 200:  100     50: LOAD_CONST(50)
# 202:   90      0: STORE_NAME(a)
#
# 204:  100     51: LOAD_CONST(51)
# 206:   90      0: STORE_NAME(a)
#
# 208:  100     52: LOAD_CONST(52)
# 210:   90      0: STORE_NAME(a)
#
# 212:  100     53: LOAD_CONST(53)
# 214:   90      0: STORE_NAME(a)
#
# 216:  100     54: LOAD_CONST(54)
# 218:   90      0: STORE_NAME(a)
#
# 220:  100     55: LOAD_CONST(55)
# 222:   90      0: STORE_NAME(a)
#
# 224:  100     56: LOAD_CONST(56)
# 226:   90      0: STORE_NAME(a)
#
# 228:  100     57: LOAD_CONST(57)
# 230:   90      0: STORE_NAME(a)
#
# 232:  100     58: LOAD_CONST(58)
# 234:   90      0: STORE_NAME(a)
#
# 236:  100     59: LOAD_CONST(59)
# 238:   90      0: STORE_NAME(a)
#
# 240:  100     60: LOAD_CONST(60)
# 242:   90      0: STORE_NAME(a)
#
# 244:  100     61: LOAD_CONST(61)
# 246:   90      0: STORE_NAME(a)
#
# 248:  100     62: LOAD_CONST(62)
# 250:   90      0: STORE_NAME(a)
#
# 252:  100     63: LOAD_CONST(63)
# 254:   90      0: STORE_NAME(a)
#
# 256:  100     64: LOAD_CONST(64)
# 258:   90      0: STORE_NAME(a)
#
# 260:  100     65: LOAD_CONST(65)
# 262:   90      0: STORE_NAME(a)
#
# 264:  100     66: LOAD_CONST(66)
# 266:   90      0: STORE_NAME(a)
#
# 268:  100     67: LOAD_CONST(67)
# 270:   90      0: STORE_NAME(a)
#
# 272:  100     68: LOAD_CONST(68)
# 274:   90      0: STORE_NAME(a)
#
# 276:  100     69: LOAD_CONST(69)
# 278:   90      0: STORE_NAME(a)
#
# 280:  100     70: LOAD_CONST(70)
# 282:   90      0: STORE_NAME(a)
#
# 284:  100     71: LOAD_CONST(71)
# 286:   90      0: STORE_NAME(a)
#
# 288:  100     72: LOAD_CONST(72)
# 290:   90      0: STORE_NAME(a)
#
# 292:  100     73: LOAD_CONST(73)
# 294:   90      0: STORE_NAME(a)
#
# 296:  100     74: LOAD_CONST(74)
# 298:   90      0: STORE_NAME(a)
#
# 300:  100     75: LOAD_CONST(75)
# 302:   90      0: STORE_NAME(a)
#
# 304:  100     76: LOAD_CONST(76)
# 306:   90      0: STORE_NAME(a)
#
# 308:  100     77: LOAD_CONST(77)
# 310:   90      0: STORE_NAME(a)
#
# 312:  100     78: LOAD_CONST(78)
# 314:   90      0: STORE_NAME(a)
#
# 316:  100     79: LOAD_CONST(79)
# 318:   90      0: STORE_NAME(a)
#
# 320:  100     80: LOAD_CONST(80)
# 322:   90      0: STORE_NAME(a)
#
# 324:  100     81: LOAD_CONST(81)
# 326:   90      0: STORE_NAME(a)
#
# 328:  100     82: LOAD_CONST(82)
# 330:   90      0: STORE_NAME(a)
#
# 332:  100     83: LOAD_CONST(83)
# 334:   90      0: STORE_NAME(a)
#
# 336:  100     84: LOAD_CONST(84)
# 338:   90      0: STORE_NAME(a)
#
# 340:  100     85: LOAD_CONST(85)
# 342:   90      0: STORE_NAME(a)
#
# 344:  100     86: LOAD_CONST(86)
# 346:   90      0: STORE_NAME(a)
#
# 348:  100     87: LOAD_CONST(87)
# 350:   90      0: STORE_NAME(a)
#
# 352:  100     88: LOAD_CONST(88)
# 354:   90      0: STORE_NAME(a)
#
# 356:  100     89: LOAD_CONST(89)
# 358:   90      0: STORE_NAME(a)
#
# 360:  100     90: LOAD_CONST(90)
# 362:   90      0: STORE_NAME(a)
#
# 364:  100     91: LOAD_CONST(91)
# 366:   90      0: STORE_NAME(a)
#
# 368:  100     92: LOAD_CONST(92)
# 370:   90      0: STORE_NAME(a)
#
# 372:  100     93: LOAD_CONST(93)
# 374:   90      0: STORE_NAME(a)
#
# 376:  100     94: LOAD_CONST(94)
# 378:   90      0: STORE_NAME(a)
#
# 380:  100     95: LOAD_CONST(95)
# 382:   90      0: STORE_NAME(a)
#
# 384:  100     96: LOAD_CONST(96)
# 386:   90      0: STORE_NAME(a)
#
# 388:  100     97: LOAD_CONST(97)
# 390:   90      0: STORE_NAME(a)
#
# 392:  100     98: LOAD_CONST(98)
# 394:   90      0: STORE_NAME(a)
#
# 396:  100     99: LOAD_CONST(99)
# 398:   90      0: STORE_NAME(a)
#
# 400:  100    100: LOAD_CONST(100)
# 402:   90      0: STORE_NAME(a)
#
# 404:  100    101: LOAD_CONST(101)
# 406:   90      0: STORE_NAME(a)
#
# 408:  100    102: LOAD_CONST(102)
# 410:   90      0: STORE_NAME(a)
#
# 412:  100    103: LOAD_CONST(103)
# 414:   90      0: STORE_NAME(a)
#
# 416:  100    104: LOAD_CONST(104)
# 418:   90      0: STORE_NAME(a)
#
# 420:  100    105: LOAD_CONST(105)
# 422:   90      0: STORE_NAME(a)
#
# 424:  100    106: LOAD_CONST(106)
# 426:   90      0: STORE_NAME(a)
#
# 428:  100    107: LOAD_CONST(107)
# 430:   90      0: STORE_NAME(a)
#
# 432:  100    108: LOAD_CONST(108)
# 434:   90      0: STORE_NAME(a)
#
# 436:  100    109: LOAD_CONST(109)
# 438:   90      0: STORE_NAME(a)
#
# 440:  100    110: LOAD_CONST(110)
# 442:   90      0: STORE_NAME(a)
#
# 444:  100    111: LOAD_CONST(111)
# 446:   90      0: STORE_NAME(a)
#
# 448:  100    112: LOAD_CONST(112)
# 450:   90      0: STORE_NAME(a)
#
# 452:  100    113: LOAD_CONST(113)
# 454:   90      0: STORE_NAME(a)
#
# 456:  100    114: LOAD_CONST(114)
# 458:   90      0: STORE_NAME(a)
#
# 460:  100    115: LOAD_CONST(115)
# 462:   90      0: STORE_NAME(a)
#
# 464:  100    116: LOAD_CONST(116)
# 466:   90      0: STORE_NAME(a)
#
# 468:  100    117: LOAD_CONST(117)
# 470:   90      0: STORE_NAME(a)
#
# 472:  100    118: LOAD_CONST(118)
# 474:   90      0: STORE_NAME(a)
#
# 476:  100    119: LOAD_CONST(119)
# 478:   90      0: STORE_NAME(a)
#
# 480:  100    120: LOAD_CONST(120)
# 482:   90      0: STORE_NAME(a)
#
# 484:  100    121: LOAD_CONST(121)
# 486:   90      0: STORE_NAME(a)
#
# 488:  100    122: LOAD_CONST(122)
# 490:   90      0: STORE_NAME(a)
#
# 492:  100    123: LOAD_CONST(123)
# 494:   90      0: STORE_NAME(a)
#
# 496:  100    124: LOAD_CONST(124)
# 498:   90      0: STORE_NAME(a)
#
# 500:  100    125: LOAD_CONST(125)
# 502:   90      0: STORE_NAME(a)
#
# 504:  100    126: LOAD_CONST(126)
# 506:   90      0: STORE_NAME(a)
#
# 508:  100    127: LOAD_CONST(127)
# 510:   90      0: STORE_NAME(a)
#
# 512:  100    128: LOAD_CONST(128)
# 514:   90      0: STORE_NAME(a)
#
# 516:  100    129: LOAD_CONST(129)
# 518:   90      0: STORE_NAME(a)
#
# 520:  100    130: LOAD_CONST(130)
# 522:   90      0: STORE_NAME(a)
#
# 524:  100    131: LOAD_CONST(131)
# 526:   90      0: STORE_NAME(a)
#
# 528:  100    132: LOAD_CONST(132)
# 530:   90      0: STORE_NAME(a)
#
# 532:  100    133: LOAD_CONST(133)
# 534:   90      0: STORE_NAME(a)
#
# 536:  100    134: LOAD_CONST(134)
# 538:   90      0: STORE_NAME(a)
#
# 540:  100    135: LOAD_CONST(135)
# 542:   90      0: STORE_NAME(a)
#
# 544:  100    136: LOAD_CONST(136)
# 546:   90      0: STORE_NAME(a)
#
# 548:  100    137: LOAD_CONST(137)
# 550:   90      0: STORE_NAME(a)
#
# 552:  100    138: LOAD_CONST(138)
# 554:   90      0: STORE_NAME(a)
#
# 556:  100    139: LOAD_CONST(139)
# 558:   90      0: STORE_NAME(a)
#
# 560:  100    140: LOAD_CONST(140)
# 562:   90      0: STORE_NAME(a)
#
# 564:  100    141: LOAD_CONST(141)
# 566:   90      0: STORE_NAME(a)
#
# 568:  100    142: LOAD_CONST(142)
# 570:   90      0: STORE_NAME(a)
#
# 572:  100    143: LOAD_CONST(143)
# 574:   90      0: STORE_NAME(a)
#
# 576:  100    144: LOAD_CONST(144)
# 578:   90      0: STORE_NAME(a)
#
# 580:  100    145: LOAD_CONST(145)
# 582:   90      0: STORE_NAME(a)
#
# 584:  100    146: LOAD_CONST(146)
# 586:   90      0: STORE_NAME(a)
#
# 588:  100    147: LOAD_CONST(147)
# 590:   90      0: STORE_NAME(a)
#
# 592:  100    148: LOAD_CONST(148)
# 594:   90      0: STORE_NAME(a)
#
# 596:  100    149: LOAD_CONST(149)
# 598:   90      0: STORE_NAME(a)
#
# 600:  100    150: LOAD_CONST(150)
# 602:   90      0: STORE_NAME(a)
#
# 604:  100    151: LOAD_CONST(151)
# 606:   90      0: STORE_NAME(a)
#
# 608:  100    152: LOAD_CONST(152)
# 610:   90      0: STORE_NAME(a)
#
# 612:  100    153: LOAD_CONST(153)
# 614:   90      0: STORE_NAME(a)
#
# 616:  100    154: LOAD_CONST(154)
# 618:   90      0: STORE_NAME(a)
#
# 620:  100    155: LOAD_CONST(155)
# 622:   90      0: STORE_NAME(a)
#
# 624:  100    156: LOAD_CONST(156)
# 626:   90      0: STORE_NAME(a)
#
# 628:  100    157: LOAD_CONST(157)
# 630:   90      0: STORE_NAME(a)
#
# 632:  100    158: LOAD_CONST(158)
# 634:   90      0: STORE_NAME(a)
#
# 636:  100    159: LOAD_CONST(159)
# 638:   90      0: STORE_NAME(a)
#
# 640:  100    160: LOAD_CONST(160)
# 642:   90      0: STORE_NAME(a)
#
# 644:  100    161: LOAD_CONST(161)
# 646:   90      0: STORE_NAME(a)
#
# 648:  100    162: LOAD_CONST(162)
# 650:   90      0: STORE_NAME(a)
#
# 652:  100    163: LOAD_CONST(163)
# 654:   90      0: STORE_NAME(a)
#
# 656:  100    164: LOAD_CONST(164)
# 658:   90      0: STORE_NAME(a)
#
# 660:  100    165: LOAD_CONST(165)
# 662:   90      0: STORE_NAME(a)
#
# 664:  100    166: LOAD_CONST(166)
# 666:   90      0: STORE_NAME(a)
#
# 668:  100    167: LOAD_CONST(167)
# 670:   90      0: STORE_NAME(a)
#
# 672:  100    168: LOAD_CONST(168)
# 674:   90      0: STORE_NAME(a)
#
# 676:  100    169: LOAD_CONST(169)
# 678:   90      0: STORE_NAME(a)
#
# 680:  100    170: LOAD_CONST(170)
# 682:   90      0: STORE_NAME(a)
#
# 684:  100    171: LOAD_CONST(171)
# 686:   90      0: STORE_NAME(a)
#
# 688:  100    172: LOAD_CONST(172)
# 690:   90      0: STORE_NAME(a)
#
# 692:  100    173: LOAD_CONST(173)
# 694:   90      0: STORE_NAME(a)
#
# 696:  100    174: LOAD_CONST(174)
# 698:   90      0: STORE_NAME(a)
#
# 700:  100    175: LOAD_CONST(175)
# 702:   90      0: STORE_NAME(a)
#
# 704:  100    176: LOAD_CONST(176)
# 706:   90      0: STORE_NAME(a)
#
# 708:  100    177: LOAD_CONST(177)
# 710:   90      0: STORE_NAME(a)
#
# 712:  100    178: LOAD_CONST(178)
# 714:   90      0: STORE_NAME(a)
#
# 716:  100    179: LOAD_CONST(179)
# 718:   90      0: STORE_NAME(a)
#
# 720:  100    180: LOAD_CONST(180)
# 722:   90      0: STORE_NAME(a)
#
# 724:  100    181: LOAD_CONST(181)
# 726:   90      0: STORE_NAME(a)
#
# 728:  100    182: LOAD_CONST(182)
# 730:   90      0: STORE_NAME(a)
#
# 732:  100    183: LOAD_CONST(183)
# 734:   90      0: STORE_NAME(a)
#
# 736:  100    184: LOAD_CONST(184)
# 738:   90      0: STORE_NAME(a)
#
# 740:  100    185: LOAD_CONST(185)
# 742:   90      0: STORE_NAME(a)
#
# 744:  100    186: LOAD_CONST(186)
# 746:   90      0: STORE_NAME(a)
#
# 748:  100    187: LOAD_CONST(187)
# 750:   90      0: STORE_NAME(a)
#
# 752:  100    188: LOAD_CONST(188)
# 754:   90      0: STORE_NAME(a)
#
# 756:  100    189: LOAD_CONST(189)
# 758:   90      0: STORE_NAME(a)
#
# 760:  100    190: LOAD_CONST(190)
# 762:   90      0: STORE_NAME(a)
#
# 764:  100    191: LOAD_CONST(191)
# 766:   90      0: STORE_NAME(a)
#
# 768:  100    192: LOAD_CONST(192)
# 770:   90      0: STORE_NAME(a)
#
# 772:  100    193: LOAD_CONST(193)
# 774:   90      0: STORE_NAME(a)
#
# 776:  100    194: LOAD_CONST(194)
# 778:   90      0: STORE_NAME(a)
#
# 780:  100    195: LOAD_CONST(195)
# 782:   90      0: STORE_NAME(a)
#
# 784:  100    196: LOAD_CONST(196)
# 786:   90      0: STORE_NAME(a)
#
# 788:  100    197: LOAD_CONST(197)
# 790:   90      0: STORE_NAME(a)
#
# 792:  100    198: LOAD_CONST(198)
# 794:   90      0: STORE_NAME(a)
#
# 796:  100    199: LOAD_CONST(199)
# 798:   90      0: STORE_NAME(a)
#
# 800:  100    200: LOAD_CONST(200)
# 802:   90      0: STORE_NAME(a)
#
# 804:  100    201: LOAD_CONST(201)
# 806:   90      0: STORE_NAME(a)
#
# 808:  100    202: LOAD_CONST(202)
# 810:   90      0: STORE_NAME(a)
#
# 812:  100    203: LOAD_CONST(203)
# 814:   90      0: STORE_NAME(a)
#
# 816:  100    204: LOAD_CONST(204)
# 818:   90      0: STORE_NAME(a)
#
# 820:  100    205: LOAD_CONST(205)
# 822:   90      0: STORE_NAME(a)
#
# 824:  100    206: LOAD_CONST(206)
# 826:   90      0: STORE_NAME(a)
#
# 828:  100    207: LOAD_CONST(207)
# 830:   90      0: STORE_NAME(a)
#
# 832:  100    208: LOAD_CONST(208)
# 834:   90      0: STORE_NAME(a)
#
# 836:  100    209: LOAD_CONST(209)
# 838:   90      0: STORE_NAME(a)
#
# 840:  100    210: LOAD_CONST(210)
# 842:   90      0: STORE_NAME(a)
#
# 844:  100    211: LOAD_CONST(211)
# 846:   90      0: STORE_NAME(a)
#
# 848:  100    212: LOAD_CONST(212)
# 850:   90      0: STORE_NAME(a)
#
# 852:  100    213: LOAD_CONST(213)
# 854:   90      0: STORE_NAME(a)
#
# 856:  100    214: LOAD_CONST(214)
# 858:   90      0: STORE_NAME(a)
#
# 860:  100    215: LOAD_CONST(215)
# 862:   90      0: STORE_NAME(a)
#
# 864:  100    216: LOAD_CONST(216)
# 866:   90      0: STORE_NAME(a)
#
# 868:  100    217: LOAD_CONST(217)
# 870:   90      0: STORE_NAME(a)
#
# 872:  100    218: LOAD_CONST(218)
# 874:   90      0: STORE_NAME(a)
#
# 876:  100    219: LOAD_CONST(219)
# 878:   90      0: STORE_NAME(a)
#
# 880:  100    220: LOAD_CONST(220)
# 882:   90      0: STORE_NAME(a)
#
# 884:  100    221: LOAD_CONST(221)
# 886:   90      0: STORE_NAME(a)
#
# 888:  100    222: LOAD_CONST(222)
# 890:   90      0: STORE_NAME(a)
#
# 892:  100    223: LOAD_CONST(223)
# 894:   90      0: STORE_NAME(a)
#
# 896:  100    224: LOAD_CONST(224)
# 898:   90      0: STORE_NAME(a)
#
# 900:  100    225: LOAD_CONST(225)
# 902:   90      0: STORE_NAME(a)
#
# 904:  100    226: LOAD_CONST(226)
# 906:   90      0: STORE_NAME(a)
#
# 908:  100    227: LOAD_CONST(227)
# 910:   90      0: STORE_NAME(a)
#
# 912:  100    228: LOAD_CONST(228)
# 914:   90      0: STORE_NAME(a)
#
# 916:  100    229: LOAD_CONST(229)
# 918:   90      0: STORE_NAME(a)
#
# 920:  100    230: LOAD_CONST(230)
# 922:   90      0: STORE_NAME(a)
#
# 924:  100    231: LOAD_CONST(231)
# 926:   90      0: STORE_NAME(a)
#
# 928:  100    232: LOAD_CONST(232)
# 930:   90      0: STORE_NAME(a)
#
# 932:  100    233: LOAD_CONST(233)
# 934:   90      0: STORE_NAME(a)
#
# 936:  100    234: LOAD_CONST(234)
# 938:   90      0: STORE_NAME(a)
#
# 940:  100    235: LOAD_CONST(235)
# 942:   90      0: STORE_NAME(a)
#
# 944:  100    236: LOAD_CONST(236)
# 946:   90      0: STORE_NAME(a)
#
# 948:  100    237: LOAD_CONST(237)
# 950:   90      0: STORE_NAME(a)
#
# 952:  100    238: LOAD_CONST(238)
# 954:   90      0: STORE_NAME(a)
#
# 956:  100    239: LOAD_CONST(239)
# 958:   90      0: STORE_NAME(a)
#
# 960:  100    240: LOAD_CONST(240)
# 962:   90      0: STORE_NAME(a)
#
# 964:  100    241: LOAD_CONST(241)
# 966:   90      0: STORE_NAME(a)
#
# 968:  100    242: LOAD_CONST(242)
# 970:   90      0: STORE_NAME(a)
#
# 972:  100    243: LOAD_CONST(243)
# 974:   90      0: STORE_NAME(a)
#
# 976:  100    244: LOAD_CONST(244)
# 978:   90      0: STORE_NAME(a)
#
# 980:  100    245: LOAD_CONST(245)
# 982:   90      0: STORE_NAME(a)
#
# 984:  100    246: LOAD_CONST(246)
# 986:   90      0: STORE_NAME(a)
#
# 988:  100    247: LOAD_CONST(247)
# 990:   90      0: STORE_NAME(a)
#
# 992:  100    248: LOAD_CONST(248)
# 994:   90      0: STORE_NAME(a)
#
# 996:  100    249: LOAD_CONST(249)
# 998:   90      0: STORE_NAME(a)
#
# 1000:  100    250: LOAD_CONST(250)
# 1002:   90      0: STORE_NAME(a)
#
# 1004:  100    251: LOAD_CONST(251)
# 1006:   90      0: STORE_NAME(a)
#
# 1008:  100    252: LOAD_CONST(252)
# 1010:   90      0: STORE_NAME(a)
#
# 1012:  100    253: LOAD_CONST(253)
# 1014:   90      0: STORE_NAME(a)
#
# 1016:  100    254: LOAD_CONST(254)
# 1018:   90      0: STORE_NAME(a)
#
# 1020:  100    255: LOAD_CONST(255)
# 1022:   90      0: STORE_NAME(a)
#
# 1024:  144      1: EXTENDED_ARG()
# 1026:  100    256: LOAD_CONST(256)
# 1028:   90      0: STORE_NAME(a)
#
# 1030:  144      1: EXTENDED_ARG()
# 1032:  100    257: LOAD_CONST(257)
# 1034:   90      0: STORE_NAME(a)
#
# 1036:  144      1: EXTENDED_ARG()
# 1038:  100    258: LOAD_CONST(258)
# 1040:   90      0: STORE_NAME(a)
#
# 1042:  144      1: EXTENDED_ARG()
# 1044:  100    259: LOAD_CONST(259)
# 1046:   90      0: STORE_NAME(a)
# 1048:  144      1: EXTENDED_ARG()
# 1050:  100    260: LOAD_CONST(None)
# 1052:   83      -: RETURN_VALUE()

# %% [markdown]
# ### Summary
# In case the argument doesn't fit in a single byte, a special `EXTENDED_ARG` operation is prepended. It supplies a byte's worth of extra data to the next instruction.

# %% [markdown]
# ---
# # Extra section II - Different Kinds of Variables

# %%
def print_dis(code):
    line_starts = [a for a, b in dis.findlinestarts(code)]
    for instr in dis.get_instructions(code):
        if instr.offset in line_starts:
            print()
        print('{i.offset:2}:  {i.opcode:3} {arg:>6}: {i.opname}({i.argrepr})'.format(
                i=instr,
                arg='-' if instr.arg is None else instr.arg))

def dump_code_attrs(code):
    print(code)
    for attr_name in dir(code):
        if not attr_name.startswith('__'):
            print('  {}: {}'.format(attr_name, getattr(code, attr_name)))

# %%
# !cat -n module.py
# Out:
#      1	a = 3
#      2	b = 'Hello '
#      3	print(a * b)
#      4
#      5	def func(a=1, *b, **c):
#      6	    return 7 + 3

# %%
filename = os.path.abspath('module.py')
with open(filename) as f:
    code = compile(f.read(), filename=filename, mode='exec')

dump_code_attrs(code)
print()
print(dis.code_info(code))
print_dis(code)
# Out:
# <code object <module> at 0x7fbc842cba00, file "/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py", line 1>
#   co_argcount: 0
#   co_cellvars: ()
#   co_code: b'd\x00Z\x00d\x01Z\x01e\x02e\x00e\x01\x14\x00\x83\x01\x01\x00d\x06d\x03d\x04\x84\x01Z\x03d\x05S\x00'
#   co_consts: (3, 'Hello ', 1, <code object func at 0x7fbc842cbc40, file "/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py", line 5>, 'func', None, (1,))
#   co_filename: /home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py
#   co_firstlineno: 1
#   co_flags: 64
#   co_freevars: ()
#   co_kwonlyargcount: 0
#   co_lnotab: b'\x04\x01\x04\x01\x0c\x02'
#   co_name: <module>
#   co_names: ('a', 'b', 'print', 'func')
#   co_nlocals: 0
#   co_stacksize: 3
#   co_varnames: ()
#
# Name:              <module>
# Filename:          /home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py
# Argument count:    0
# Kw-only arguments: 0
# Number of locals:  0
# Stack size:        3
# Flags:             NOFREE
# Constants:
#    0: 3
#    1: 'Hello '
#    2: 1
#    3: <code object func at 0x7fbc842cbc40, file "/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py", line 5>
#    4: 'func'
#    5: None
#    6: (1,)
# Names:
#    0: a
#    1: b
#    2: print
#    3: func
#
#  0:  100      0: LOAD_CONST(3)
#  2:   90      0: STORE_NAME(a)
#
#  4:  100      1: LOAD_CONST('Hello ')
#  6:   90      1: STORE_NAME(b)
#
#  8:  101      2: LOAD_NAME(print)
# 10:  101      0: LOAD_NAME(a)
# 12:  101      1: LOAD_NAME(b)
# 14:   20      -: BINARY_MULTIPLY()
# 16:  131      1: CALL_FUNCTION(1 positional, 0 keyword pair)
# 18:    1      -: POP_TOP()
#
# 20:  100      6: LOAD_CONST((1,))
# 22:  100      3: LOAD_CONST(<code object func at 0x7fbc842cbc40, file "/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py", line 5>)
# 24:  100      4: LOAD_CONST('func')
# 26:  132      1: MAKE_FUNCTION()
# 28:   90      3: STORE_NAME(func)
# 30:  100      5: LOAD_CONST(None)
# 32:   83      -: RETURN_VALUE()

# %%
n = 3
def repeat_string(a):
    b = 'hello'
    return a * n * b

dump_code_attrs(repeat_string.__code__)
print()
print(dis.code_info(repeat_string.__code__))
print_dis(repeat_string.__code__)
# Out:
# <code object repeat_string at 0x7fbc842cb640, file "<ipython-input-15-3410d72e56a2>", line 2>
#   co_argcount: 1
#   co_cellvars: ()
#   co_code: b'd\x01}\x01|\x00t\x00\x14\x00|\x01\x14\x00S\x00'
#   co_consts: (None, 'hello')
#   co_filename: <ipython-input-15-3410d72e56a2>
#   co_firstlineno: 2
#   co_flags: 67
#   co_freevars: ()
#   co_kwonlyargcount: 0
#   co_lnotab: b'\x00\x01\x04\x01'
#   co_name: repeat_string
#   co_names: ('n',)
#   co_nlocals: 2
#   co_stacksize: 2
#   co_varnames: ('a', 'b')
#
# Name:              repeat_string
# Filename:          <ipython-input-15-3410d72e56a2>
# Argument count:    1
# Kw-only arguments: 0
# Number of locals:  2
# Stack size:        2
# Flags:             OPTIMIZED, NEWLOCALS, NOFREE
# Constants:
#    0: None
#    1: 'hello'
# Names:
#    0: n
# Variable names:
#    0: a
#    1: b
#
#  0:  100      1: LOAD_CONST('hello')
#  2:  125      1: STORE_FAST(b)
#
#  4:  124      0: LOAD_FAST(a)
#  6:  116      0: LOAD_GLOBAL(n)
#  8:   20      -: BINARY_MULTIPLY()
# 10:  124      1: LOAD_FAST(b)
# 12:   20      -: BINARY_MULTIPLY()
# 14:   83      -: RETURN_VALUE()

# %%
a = 3
def make_class():
    class SomeClass:
        b = 'hello'
        print(a * b)

consts = make_class.__code__.co_consts
print(dict(enumerate(type(t).__name__ for t in consts)))

class_code = consts[1]
print()
dump_code_attrs(class_code)
print()
print(dis.code_info(class_code))
print_dis(class_code)

# %% [markdown]
# ### Summary
# There are several different kinds of variables:
#
# * Named variables, which are always looked up by name. Module-level code uses these, and they're also used by class code.
# * Global variables, which are looked up by name in the global (module) namespace. Functions and classes use these when needed.
# * "Fast local" variables, which are accessed by index, so the access is very fast. Functions use these. This means functions need to know all names of variables at compile time, which is why `import *` is not allowed in functions.
# * (There are also cell variables, which are used in closures to access the outer namespace.)

# %%
import module
# Out:
# Hello Hello Hello

# %%
module.__dict__
# Out:
# {'__builtins__': {'ArithmeticError': ArithmeticError,
#   'AssertionError': AssertionError,
#   'AttributeError': AttributeError,
#   'BaseException': BaseException,
#   'BlockingIOError': BlockingIOError,
#   'BrokenPipeError': BrokenPipeError,
#   'BufferError': BufferError,
#   'BytesWarning': BytesWarning,
#   'ChildProcessError': ChildProcessError,
#   'ConnectionAbortedError': ConnectionAbortedError,
#   'ConnectionError': ConnectionError,
#   'ConnectionRefusedError': ConnectionRefusedError,
#   'ConnectionResetError': ConnectionResetError,
#   'DeprecationWarning': DeprecationWarning,
#   'EOFError': EOFError,
#   'Ellipsis': Ellipsis,
#   'EnvironmentError': OSError,
#   'Exception': Exception,
#   'False': False,
#   'FileExistsError': FileExistsError,
#   'FileNotFoundError': FileNotFoundError,
#   'FloatingPointError': FloatingPointError,
#   'FutureWarning': FutureWarning,
#   'GeneratorExit': GeneratorExit,
#   'IOError': OSError,
#   'ImportError': ImportError,
#   'ImportWarning': ImportWarning,
#   'IndentationError': IndentationError,
#   'IndexError': IndexError,
#   'InterruptedError': InterruptedError,
#   'IsADirectoryError': IsADirectoryError,
#   'KeyError': KeyError,
#   'KeyboardInterrupt': KeyboardInterrupt,
#   'LookupError': LookupError,
#   'MemoryError': MemoryError,
#   'NameError': NameError,
#   'None': None,
#   'NotADirectoryError': NotADirectoryError,
#   'NotImplemented': NotImplemented,
#   'NotImplementedError': NotImplementedError,
#   'OSError': OSError,
#   'OverflowError': OverflowError,
#   'PendingDeprecationWarning': PendingDeprecationWarning,
#   'PermissionError': PermissionError,
#   'ProcessLookupError': ProcessLookupError,
#   'RecursionError': RecursionError,
#   'ReferenceError': ReferenceError,
#   'ResourceWarning': ResourceWarning,
#   'RuntimeError': RuntimeError,
#   'RuntimeWarning': RuntimeWarning,
#   'StopAsyncIteration': StopAsyncIteration,
#   'StopIteration': StopIteration,
#   'SyntaxError': SyntaxError,
#   'SyntaxWarning': SyntaxWarning,
#   'SystemError': SystemError,
#   'SystemExit': SystemExit,
#   'TabError': TabError,
#   'TimeoutError': TimeoutError,
#   'True': True,
#   'TypeError': TypeError,
#   'UnboundLocalError': UnboundLocalError,
#   'UnicodeDecodeError': UnicodeDecodeError,
#   'UnicodeEncodeError': UnicodeEncodeError,
#   'UnicodeError': UnicodeError,
#   'UnicodeTranslateError': UnicodeTranslateError,
#   'UnicodeWarning': UnicodeWarning,
#   'UserWarning': UserWarning,
#   'ValueError': ValueError,
#   'Warning': Warning,
#   'ZeroDivisionError': ZeroDivisionError,
#   '__IPYTHON__': True,
#   '__IPYTHON__active': 'Deprecated, check for __IPYTHON__',
#   '__build_class__': <function __build_class__>,
#   '__debug__': True,
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__import__': <function __import__>,
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__name__': 'builtins',
#   '__package__': '',
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter' at 0x1d0c088>),
#   'abs': <function abs>,
#   'all': <function all>,
#   'any': <function any>,
#   'ascii': <function ascii>,
#   'bin': <function bin>,
#   'bool': bool,
#   'bytearray': bytearray,
#   'bytes': bytes,
#   'callable': <function callable>,
#   'chr': <function chr>,
#   'classmethod': classmethod,
#   'compile': <function compile>,
#   'complex': complex,
#   'copyright': Copyright (c) 2001-2016 Python Software Foundation.
#   All Rights Reserved.
#
#   Copyright (c) 2000 BeOpen.com.
#   All Rights Reserved.
#
#   Copyright (c) 1995-2001 Corporation for National Research Initiatives.
#   All Rights Reserved.
#
#   Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
#   All Rights Reserved.,
#   'credits':     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#       for supporting Python development.  See www.python.org for more information.,
#   'delattr': <function delattr>,
#   'dict': dict,
#   'dir': <function dir>,
#   'divmod': <function divmod>,
#   'dreload': <function IPython.lib.deepreload._dreload>,
#   'enumerate': enumerate,
#   'eval': <function eval>,
#   'exec': <function exec>,
#   'filter': filter,
#   'float': float,
#   'format': <function format>,
#   'frozenset': frozenset,
#   'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fbc85c4f7a8>>,
#   'getattr': <function getattr>,
#   'globals': <function globals>,
#   'hasattr': <function hasattr>,
#   'hash': <function hash>,
#   'help': Type help() for interactive help, or help(object) for help about object.,
#   'hex': <function hex>,
#   'id': <function id>,
#   'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7fbc85c4f740>>,
#   'int': int,
#   'isinstance': <function isinstance>,
#   'issubclass': <function issubclass>,
#   'iter': <function iter>,
#   'len': <function len>,
#   'license': Type license() to see the full license text,
#   'list': list,
#   'locals': <function locals>,
#   'map': map,
#   'max': <function max>,
#   'memoryview': memoryview,
#   'min': <function min>,
#   'next': <function next>,
#   'object': object,
#   'oct': <function oct>,
#   'open': <function io.open>,
#   'ord': <function ord>,
#   'pow': <function pow>,
#   'print': <function print>,
#   'property': property,
#   'range': range,
#   'repr': <function repr>,
#   'reversed': reversed,
#   'round': <function round>,
#   'set': set,
#   'setattr': <function setattr>,
#   'slice': slice,
#   'sorted': <function sorted>,
#   'staticmethod': staticmethod,
#   'str': str,
#   'sum': <function sum>,
#   'super': super,
#   'tuple': tuple,
#   'type': type,
#   'vars': <function vars>,
#   'zip': zip},
#  '__cached__': '/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/__pycache__/module.cpython-36.pyc',
#  '__doc__': None,
#  '__file__': '/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7fbc84296d58>,
#  '__name__': 'module',
#  '__package__': '',
#  '__spec__': ModuleSpec(name='module', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fbc84296d58>, origin='/home/pviktori/dev/slides/2016-06-22-pysilesia-bytecode/module.py'),
#  'a': 3,
#  'b': 'Hello ',
#  'func': <function module.func>}

# %%
module.func.__globals__['f'] = 3

# %%
module.f
# Out:
# 3

# %%
module.__dict__['f']
# Out:
# 3

# %%
class Foo:
    ...

Foo.f = 123
Foo.__add__ = lambda self, other: self + other

# %%
dct = {'a': 1, 'b': 2}
yeah = type(Foo.__dict__)(dct)

# %%
yeah['a']
# Out:
# 1

# %%
dct[5] = 6
yeah[5]
# Out:
# 6

# %%
type(4)("9")
# Out:
# 9
